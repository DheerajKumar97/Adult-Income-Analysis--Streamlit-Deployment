# %% [markdown]
# ### **Connect With Me in Linkedin** :- https://www.linkedin.com/in/dheerajkumar1997/

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# from flask import Flask, render_template, request

# %% [markdown]
# # Import Data

# %%
ad = pd.read_csv('E:/Downlload/adult.csv')

# %%
ad
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                      ?  Not-in-family  White  Female             0
# 1        Exec-managerial  Not-in-family  White  Female             0
# 2                      ?      Unmarried  Black  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 1              4356              18  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# # Data Visualization

# %%
ad.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021246C1A748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021246F12388>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021246F4D1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021246F81F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021246FBCEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021246FF5D88>]],
#       dtype=object)

# %%
ad.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
# fig_dims = (15, 5)
# fig, ax = plt.subplots(figsize=fig_dims)
sns.catplot(x="capital.loss", y="sex",  hue="sex",data=ad)

# %%
sns.catplot(x="education.num", y="sex",  hue="sex",data=ad)

# %%
fig_dims = (15, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="hours.per.week", y="education",  hue="sex",data=ad,ax=ax)

# %%
fig_dims = (15, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="age", y="race",  hue="sex",data=ad,ax=ax)

# %%
fig_dims = (15, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="age", y="income",  hue="sex",data=ad,ax=ax)

# %%
fig_dims = (15, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="capital.gain", y="income",  hue="sex",data=ad,ax=ax)

# %%
fig_dims = (15, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="fnlwgt", y="education",  hue="sex",data=ad,ax=ax)

# %%
sns.violinplot(x=ad['fnlwgt'],y=ad['income'],hue='sex',data=ad)

# %%
sns.violinplot(x=ad['workclass'],y=ad['age'],data=ad)

# %%
plt.scatter(x=ad['age'],y=ad['race'])

# %%
sns.violinplot(x=ad['education.num'],y=ad['sex'],data=ad)

# %%
sns.violinplot(x=ad['age'],y=ad['income'],data=ad)

# %%
# fig_dims = (18, 7)
# fig, ax = plt.subplots(figsize=fig_dims)
# sns.violinplot(x="age", y="native.country",  hue="race",data=ad,ax=ax)
plt.rcParams["figure.figsize"] = 12,8
plt.scatter(ad['age'],ad['native.country'])

# %%
sns.pairplot(ad)

# %%
sns.heatmap(ad.corr(), annot=True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Drop rows with question mark

# %%
ad = ad[(ad.astype(str) != '?').all(axis=1)]

# %%
ad=ad.reset_index(drop=True)

# %%
ad
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       82   Private  132870       HS-grad              9             Widowed
# 1       54   Private  140359       7th-8th              4            Divorced
# 2       41   Private  264663  Some-college             10           Separated
# 3       34   Private  216864       HS-grad              9            Divorced
# 4       38   Private  150601          10th              6           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 30157   22   Private  310152  Some-college             10       Never-married
# 30158   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 30159   40   Private  154374       HS-grad              9  Married-civ-spouse
# 30160   58   Private  151910       HS-grad              9             Widowed
# 30161   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0        Exec-managerial  Not-in-family  White  Female             0
# 1      Machine-op-inspct      Unmarried  White  Female             0
# 2         Prof-specialty      Own-child  White  Female             0
# 3          Other-service      Unmarried  White  Female             0
# 4           Adm-clerical      Unmarried  White    Male             0
# ...                  ...            ...    ...     ...           ...
# 30157    Protective-serv  Not-in-family  White    Male             0
# 30158       Tech-support           Wife  White  Female             0
# 30159  Machine-op-inspct        Husband  White    Male             0
# 30160       Adm-clerical      Unmarried  White  Female             0
# 30161       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              18  United-States  <=50K
# 1              3900              40  United-States  <=50K
# 2              3900              40  United-States  <=50K
# 3              3770              45  United-States  <=50K
# 4              3770              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 30157             0              40  United-States  <=50K
# 30158             0              38  United-States  <=50K
# 30159             0              40  United-States   >50K
# 30160             0              40  United-States  <=50K
# 30161             0              20  United-States  <=50K
#
# [30162 rows x 15 columns]

# %%
ad.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Remove Hyphen form DataSet

# %%
ad['education']=ad.education.str.replace('-','')

# %%
ad['marital.status'] =  ad['marital.status'].str.replace('-','')

# %%
ad['occupation'] =  ad['occupation'].str.replace('-','')

# %%
ad['relationship'] =  ad['relationship'].str.replace('-','')

# %%
ad['native.country'] =  ad['native.country'].str.replace('-','')

# %%
ad
# Out:
#        age workclass  fnlwgt    education  education.num    marital.status  \
# 0       82   Private  132870       HSgrad              9           Widowed
# 1       54   Private  140359       7th8th              4          Divorced
# 2       41   Private  264663  Somecollege             10         Separated
# 3       34   Private  216864       HSgrad              9          Divorced
# 4       38   Private  150601         10th              6         Separated
# ...    ...       ...     ...          ...            ...               ...
# 30157   22   Private  310152  Somecollege             10      Nevermarried
# 30158   27   Private  257302    Assocacdm             12  Marriedcivspouse
# 30159   40   Private  154374       HSgrad              9  Marriedcivspouse
# 30160   58   Private  151910       HSgrad              9           Widowed
# 30161   22   Private  201490       HSgrad              9      Nevermarried
#
#             occupation relationship   race     sex  capital.gain  \
# 0       Execmanagerial  Notinfamily  White  Female             0
# 1      Machineopinspct    Unmarried  White  Female             0
# 2        Profspecialty     Ownchild  White  Female             0
# 3         Otherservice    Unmarried  White  Female             0
# 4          Admclerical    Unmarried  White    Male             0
# ...                ...          ...    ...     ...           ...
# 30157   Protectiveserv  Notinfamily  White    Male             0
# 30158      Techsupport         Wife  White  Female             0
# 30159  Machineopinspct      Husband  White    Male             0
# 30160      Admclerical    Unmarried  White  Female             0
# 30161      Admclerical     Ownchild  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              18   UnitedStates  <=50K
# 1              3900              40   UnitedStates  <=50K
# 2              3900              40   UnitedStates  <=50K
# 3              3770              45   UnitedStates  <=50K
# 4              3770              40   UnitedStates  <=50K
# ...             ...             ...            ...    ...
# 30157             0              40   UnitedStates  <=50K
# 30158             0              38   UnitedStates  <=50K
# 30159             0              40   UnitedStates   >50K
# 30160             0              40   UnitedStates  <=50K
# 30161             0              20   UnitedStates  <=50K
#
# [30162 rows x 15 columns]

# %%
ad.workclass.value_counts()
# Out:
# Private             22286
# Self-emp-not-inc     2499
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Without-pay            14
# Name: workclass, dtype: int64

# %%
ad.education.value_counts()
# Out:
# HSgrad         9840
# Somecollege    6678
# Bachelors      5044
# Masters        1627
# Assocvoc       1307
# 11th           1048
# Assocacdm      1008
# 10th            820
# 7th8th          557
# Profschool      542
# 9th             455
# 12th            377
# Doctorate       375
# 5th6th          288
# 1st4th          151
# Preschool        45
# Name: education, dtype: int64

# %%
cat_num = [var for var in ad.columns if ad[var].dtypes =="object"]
cat_num = ad[cat_num]
cat_num
# Out:
#       workclass    education    marital.status       occupation relationship  \
# 0       Private       HSgrad           Widowed   Execmanagerial  Notinfamily
# 1       Private       7th8th          Divorced  Machineopinspct    Unmarried
# 2       Private  Somecollege         Separated    Profspecialty     Ownchild
# 3       Private       HSgrad          Divorced     Otherservice    Unmarried
# 4       Private         10th         Separated      Admclerical    Unmarried
# ...         ...          ...               ...              ...          ...
# 30157   Private  Somecollege      Nevermarried   Protectiveserv  Notinfamily
# 30158   Private    Assocacdm  Marriedcivspouse      Techsupport         Wife
# 30159   Private       HSgrad  Marriedcivspouse  Machineopinspct      Husband
# 30160   Private       HSgrad           Widowed      Admclerical    Unmarried
# 30161   Private       HSgrad      Nevermarried      Admclerical     Ownchild
#
#         race     sex native.country income
# 0      White  Female   UnitedStates  <=50K
# 1      White  Female   UnitedStates  <=50K
# 2      White  Female   UnitedStates  <=50K
# 3      White  Female   UnitedStates  <=50K
# 4      White    Male   UnitedStates  <=50K
# ...      ...     ...            ...    ...
# 30157  White    Male   UnitedStates  <=50K
# 30158  White  Female   UnitedStates  <=50K
# 30159  White    Male   UnitedStates   >50K
# 30160  White  Female   UnitedStates  <=50K
# 30161  White    Male   UnitedStates  <=50K
#
# [30162 rows x 9 columns]

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
#label Encoder
category_col =['workclass', 'race', 'education','Marital_Status', 'occupation',
               'relationship', 'sex', 'native.country'] 
labelEncoder = preprocessing.LabelEncoder()

# %%
ad= ad.rename(columns={'marital.status':'Marital_Status','education.num':'education_num'})
ad
# Out:
#        age workclass  fnlwgt    education  education_num    Marital_Status  \
# 0       82   Private  132870       HSgrad              9           Widowed
# 1       54   Private  140359       7th8th              4          Divorced
# 2       41   Private  264663  Somecollege             10         Separated
# 3       34   Private  216864       HSgrad              9          Divorced
# 4       38   Private  150601         10th              6         Separated
# ...    ...       ...     ...          ...            ...               ...
# 30157   22   Private  310152  Somecollege             10      Nevermarried
# 30158   27   Private  257302    Assocacdm             12  Marriedcivspouse
# 30159   40   Private  154374       HSgrad              9  Marriedcivspouse
# 30160   58   Private  151910       HSgrad              9           Widowed
# 30161   22   Private  201490       HSgrad              9      Nevermarried
#
#             occupation relationship   race     sex  capital.gain  \
# 0       Execmanagerial  Notinfamily  White  Female             0
# 1      Machineopinspct    Unmarried  White  Female             0
# 2        Profspecialty     Ownchild  White  Female             0
# 3         Otherservice    Unmarried  White  Female             0
# 4          Admclerical    Unmarried  White    Male             0
# ...                ...          ...    ...     ...           ...
# 30157   Protectiveserv  Notinfamily  White    Male             0
# 30158      Techsupport         Wife  White  Female             0
# 30159  Machineopinspct      Husband  White    Male             0
# 30160      Admclerical    Unmarried  White  Female             0
# 30161      Admclerical     Ownchild  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              18   UnitedStates  <=50K
# 1              3900              40   UnitedStates  <=50K
# 2              3900              40   UnitedStates  <=50K
# 3              3770              45   UnitedStates  <=50K
# 4              3770              40   UnitedStates  <=50K
# ...             ...             ...            ...    ...
# 30157             0              40   UnitedStates  <=50K
# 30158             0              38   UnitedStates  <=50K
# 30159             0              40   UnitedStates   >50K
# 30160             0              40   UnitedStates  <=50K
# 30161             0              20   UnitedStates  <=50K
#
# [30162 rows x 15 columns]

# %%
mapping_dict={}
for col in category_col:
    ad[col] = labelEncoder.fit_transform(ad[col])
    le_name_mapping = dict(zip(labelEncoder.classes_, labelEncoder.transform(labelEncoder.classes_)))
    mapping_dict[col]=le_name_mapping
print(mapping_dict)
# Out:
# {'workclass': {'Federal-gov': 0, 'Local-gov': 1, 'Private': 2, 'Self-emp-inc': 3, 'Self-emp-not-inc': 4, 'State-gov': 5, 'Without-pay': 6}, 'race': {'Amer-Indian-Eskimo': 0, 'Asian-Pac-Islander': 1, 'Black': 2, 'Other': 3, 'White': 4}, 'education': {'10th': 0, '11th': 1, '12th': 2, '1st4th': 3, '5th6th': 4, '7th8th': 5, '9th': 6, 'Assocacdm': 7, 'Assocvoc': 8, 'Bachelors': 9, 'Doctorate': 10, 'HSgrad': 11, 'Masters': 12, 'Preschool': 13, 'Profschool': 14, 'Somecollege': 15}, 'Marital_Status': {'Divorced': 0, 'MarriedAFspouse': 1, 'Marriedcivspouse': 2, 'Marriedspouseabsent': 3, 'Nevermarried': 4, 'Separated': 5, 'Widowed': 6}, 'occupation': {'Admclerical': 0, 'ArmedForces': 1, 'Craftrepair': 2, 'Execmanagerial': 3, 'Farmingfishing': 4, 'Handlerscleaners': 5, 'Machineopinspct': 6, 'Otherservice': 7, 'Privhouseserv': 8, 'Profspecialty': 9, 'Protectiveserv': 10, 'Sales': 11, 'Techsupport': 12, 'Transportmoving': 13}, 'relationship': {'Husband': 0, 'Notinfamily': 1, 'Otherrelative': 2, 'Ownchild': 3, 'Unmarried': 4, 'Wife': 5}, 'sex': {'Female': 0, 'Male': 1}, 'native.country': {'Cambodia': 0, 'Canada': 1, 'China': 2, 'Columbia': 3, 'Cuba': 4, 'DominicanRepublic': 5, 'Ecuador': 6, 'ElSalvador': 7, 'England': 8, 'France': 9, 'Germany': 10, 'Greece': 11, 'Guatemala': 12, 'Haiti': 13, 'HolandNetherlands': 14, 'Honduras': 15, 'Hong': 16, 'Hungary': 17, 'India': 18, 'Iran': 19, 'Ireland': 20, 'Italy': 21, 'Jamaica': 22, 'Japan': 23, 'Laos': 24, 'Mexico': 25, 'Nicaragua': 26, 'OutlyingUS(GuamUSVIetc)': 27, 'Peru': 28, 'Philippines': 29, 'Poland': 30, 'Portugal': 31, 'PuertoRico': 32, 'Scotland': 33, 'South': 34, 'Taiwan': 35, 'Thailand': 36, 'Trinadad&Tobago': 37, 'UnitedStates': 38, 'Vietnam': 39, 'Yugoslavia': 40}}

# %%
ad
# Out:
#        age  workclass  fnlwgt  education  education_num  Marital_Status  \
# 0       82          2  132870         11              9               6
# 1       54          2  140359          5              4               0
# 2       41          2  264663         15             10               5
# 3       34          2  216864         11              9               0
# 4       38          2  150601          0              6               5
# ...    ...        ...     ...        ...            ...             ...
# 30157   22          2  310152         15             10               4
# 30158   27          2  257302          7             12               2
# 30159   40          2  154374         11              9               2
# 30160   58          2  151910         11              9               6
# 30161   22          2  201490         11              9               4
#
#        occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0               3             1     4    0             0          4356
# 1               6             4     4    0             0          3900
# 2               9             3     4    0             0          3900
# 3               7             4     4    0             0          3770
# 4               0             4     4    1             0          3770
# ...           ...           ...   ...  ...           ...           ...
# 30157          10             1     4    1             0             0
# 30158          12             5     4    0             0             0
# 30159           6             0     4    1             0             0
# 30160           0             4     4    0             0             0
# 30161           0             3     4    1             0             0
#
#        hours.per.week  native.country income
# 0                  18              38  <=50K
# 1                  40              38  <=50K
# 2                  40              38  <=50K
# 3                  45              38  <=50K
# 4                  40              38  <=50K
# ...               ...             ...    ...
# 30157              40              38  <=50K
# 30158              38              38  <=50K
# 30159              40              38   >50K
# 30160              40              38  <=50K
# 30161              20              38  <=50K
#
# [30162 rows x 15 columns]

# %% [markdown]
# #### Checking for Outiers

# %%
plt.rcParams["figure.figsize"] = 12,8
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,3)


axes[0,0].set_title("fnlwgt")
axes[0,0].boxplot(ad['fnlwgt'])
axes[0,1].set_title("capital.loss")
axes[0,1].boxplot(ad['capital.loss'])
axes[0,2].set_title("hours.per.week")
axes[0,2].boxplot(ad['hours.per.week'])



axes[1,0].set_title("education")
axes[1,0].boxplot(ad['education'])
axes[1,1].set_title("occupation")
axes[1,1].boxplot(ad['occupation'])
axes[1,2].set_title("native.country")
axes[1,2].boxplot(ad['native.country'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2124e166b88>,
#   <matplotlib.lines.Line2D at 0x2124e16a988>],
#  'caps': [<matplotlib.lines.Line2D at 0x2124e16aac8>,
#   <matplotlib.lines.Line2D at 0x2124e170948>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2124e105708>],
#  'medians': [<matplotlib.lines.Line2D at 0x2124e170a88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2124e176948>],
#  'means': []}

# %% [markdown]
# ### Power Tranformation

# %%
a=ad

# %%
a=a.select_dtypes(exclude="object")

# %%
a = a.drop(['sex'],axis=1)

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
a=pt.fit_transform(a)
a
# Out:
# array([[ 2.52404089, -0.13183203, -0.43254348, ...,  4.48738793,
#         -1.93273454,  0.29779565],
#        [ 1.16039133, -0.13183203, -0.34662473, ...,  4.48738793,
#         -0.0710338 ,  0.29779565],
#        [ 0.32362285, -0.13183203,  0.80456216, ...,  4.48738793,
#         -0.0710338 ,  0.29779565],
#        ...,
#        [ 0.25094091, -0.13183203, -0.19273356, ..., -0.22284679,
#         -0.0710338 ,  0.29779565],
#        [ 1.38545721, -0.13183203, -0.21918202, ..., -0.22284679,
#         -0.0710338 ,  0.29779565],
#        [-1.39528296, -0.13183203,  0.27198071, ..., -0.22284679,
#         -1.76065891,  0.29779565]])

# %%
a = pd.DataFrame(a)
a
# Out:
#               0         1         2         3         4         5         6  \
# 0      2.524041 -0.131832 -0.432543  0.082857 -0.482678  2.199022 -0.637186
# 1      1.160391 -0.131832 -0.346625 -1.450510 -2.214234 -1.772177  0.132682
# 2      0.323623 -0.131832  0.804562  1.400923 -0.091105  1.577217  0.783631
# 3     -0.218002 -0.131832  0.409650  0.082857 -0.482678 -1.772177  0.359605
# 4      0.101174 -0.131832 -0.233334 -2.184811 -1.571889  1.577217 -1.704190
# ...         ...       ...       ...       ...       ...       ...       ...
# 30157 -1.395283 -0.131832  1.143405  1.400923 -0.091105  0.944731  0.983514
# 30158 -0.855539 -0.131832  0.746620 -1.005534  0.729630 -0.363225  1.363832
# 30159  0.250941 -0.131832 -0.192734  0.082857 -0.482678 -0.363225  0.132682
# 30160  1.385457 -0.131832 -0.219182  0.082857 -0.482678  2.199022 -1.704190
# 30161 -1.395283 -0.131832  0.271981  0.082857 -0.482678  0.944731 -1.704190
#
#               7         8         9        10        11        12
# 0      0.167201  0.403721 -0.303112  4.487388 -1.932735  0.297796
# 1      1.362691  0.403721 -0.303112  4.487388 -0.071034  0.297796
# 2      1.110955  0.403721 -0.303112  4.487388 -0.071034  0.297796
# 3      1.362691  0.403721 -0.303112  4.487388  0.344869  0.297796
# 4      1.362691  0.403721 -0.303112  4.487388 -0.071034  0.297796
# ...         ...       ...       ...       ...       ...       ...
# 30157  0.167201  0.403721 -0.303112 -0.222847 -0.071034  0.297796
# 30158  1.552174  0.403721 -0.303112 -0.222847 -0.237999  0.297796
# 30159 -1.081627  0.403721 -0.303112 -0.222847 -0.071034  0.297796
# 30160  1.362691  0.403721 -0.303112 -0.222847 -0.071034  0.297796
# 30161  1.110955  0.403721 -0.303112 -0.222847 -1.760659  0.297796
#
# [30162 rows x 13 columns]

# %%
a = a.rename(columns={0:'age',1:'workclass',2:'fnlwgt',3:'education',4:'education_num',5:'Marital_Status',6:'occupation',7:'relationship',8:'race',9:'Capital_gain',10:'Capital_loss',11:'hours_per_week',12:'native_country'})
a
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      2.524041  -0.131832 -0.432543   0.082857      -0.482678
# 1      1.160391  -0.131832 -0.346625  -1.450510      -2.214234
# 2      0.323623  -0.131832  0.804562   1.400923      -0.091105
# 3     -0.218002  -0.131832  0.409650   0.082857      -0.482678
# 4      0.101174  -0.131832 -0.233334  -2.184811      -1.571889
# ...         ...        ...       ...        ...            ...
# 30157 -1.395283  -0.131832  1.143405   1.400923      -0.091105
# 30158 -0.855539  -0.131832  0.746620  -1.005534       0.729630
# 30159  0.250941  -0.131832 -0.192734   0.082857      -0.482678
# 30160  1.385457  -0.131832 -0.219182   0.082857      -0.482678
# 30161 -1.395283  -0.131832  0.271981   0.082857      -0.482678
#
#        Marital_Status  occupation  relationship      race  Capital_gain  \
# 0            2.199022   -0.637186      0.167201  0.403721     -0.303112
# 1           -1.772177    0.132682      1.362691  0.403721     -0.303112
# 2            1.577217    0.783631      1.110955  0.403721     -0.303112
# 3           -1.772177    0.359605      1.362691  0.403721     -0.303112
# 4            1.577217   -1.704190      1.362691  0.403721     -0.303112
# ...               ...         ...           ...       ...           ...
# 30157        0.944731    0.983514      0.167201  0.403721     -0.303112
# 30158       -0.363225    1.363832      1.552174  0.403721     -0.303112
# 30159       -0.363225    0.132682     -1.081627  0.403721     -0.303112
# 30160        2.199022   -1.704190      1.362691  0.403721     -0.303112
# 30161        0.944731   -1.704190      1.110955  0.403721     -0.303112
#
#        Capital_loss  hours_per_week  native_country
# 0          4.487388       -1.932735        0.297796
# 1          4.487388       -0.071034        0.297796
# 2          4.487388       -0.071034        0.297796
# 3          4.487388        0.344869        0.297796
# 4          4.487388       -0.071034        0.297796
# ...             ...             ...             ...
# 30157     -0.222847       -0.071034        0.297796
# 30158     -0.222847       -0.237999        0.297796
# 30159     -0.222847       -0.071034        0.297796
# 30160     -0.222847       -0.071034        0.297796
# 30161     -0.222847       -1.760659        0.297796
#
# [30162 rows x 13 columns]

# %%
import pickle
pickle.dump(pt,open('powertransAD.pkl','wb'))

# %%
dd=ad['income']
dd = pd.DataFrame(dd)
dd
# Out:
#       income
# 0      <=50K
# 1      <=50K
# 2      <=50K
# 3      <=50K
# 4      <=50K
# ...      ...
# 30157  <=50K
# 30158  <=50K
# 30159   >50K
# 30160  <=50K
# 30161  <=50K
#
# [30162 rows x 1 columns]

# %%
a = pd.concat([a,dd],axis=1)

# %%
a
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      2.524041  -0.131832 -0.432543   0.082857      -0.482678
# 1      1.160391  -0.131832 -0.346625  -1.450510      -2.214234
# 2      0.323623  -0.131832  0.804562   1.400923      -0.091105
# 3     -0.218002  -0.131832  0.409650   0.082857      -0.482678
# 4      0.101174  -0.131832 -0.233334  -2.184811      -1.571889
# ...         ...        ...       ...        ...            ...
# 30157 -1.395283  -0.131832  1.143405   1.400923      -0.091105
# 30158 -0.855539  -0.131832  0.746620  -1.005534       0.729630
# 30159  0.250941  -0.131832 -0.192734   0.082857      -0.482678
# 30160  1.385457  -0.131832 -0.219182   0.082857      -0.482678
# 30161 -1.395283  -0.131832  0.271981   0.082857      -0.482678
#
#        Marital_Status  occupation  relationship      race  Capital_gain  \
# 0            2.199022   -0.637186      0.167201  0.403721     -0.303112
# 1           -1.772177    0.132682      1.362691  0.403721     -0.303112
# 2            1.577217    0.783631      1.110955  0.403721     -0.303112
# 3           -1.772177    0.359605      1.362691  0.403721     -0.303112
# 4            1.577217   -1.704190      1.362691  0.403721     -0.303112
# ...               ...         ...           ...       ...           ...
# 30157        0.944731    0.983514      0.167201  0.403721     -0.303112
# 30158       -0.363225    1.363832      1.552174  0.403721     -0.303112
# 30159       -0.363225    0.132682     -1.081627  0.403721     -0.303112
# 30160        2.199022   -1.704190      1.362691  0.403721     -0.303112
# 30161        0.944731   -1.704190      1.110955  0.403721     -0.303112
#
#        Capital_loss  hours_per_week  native_country income
# 0          4.487388       -1.932735        0.297796  <=50K
# 1          4.487388       -0.071034        0.297796  <=50K
# 2          4.487388       -0.071034        0.297796  <=50K
# 3          4.487388        0.344869        0.297796  <=50K
# 4          4.487388       -0.071034        0.297796  <=50K
# ...             ...             ...             ...    ...
# 30157     -0.222847       -0.071034        0.297796  <=50K
# 30158     -0.222847       -0.237999        0.297796  <=50K
# 30159     -0.222847       -0.071034        0.297796   >50K
# 30160     -0.222847       -0.071034        0.297796  <=50K
# 30161     -0.222847       -1.760659        0.297796  <=50K
#
# [30162 rows x 14 columns]

# %%
a.dtypes
# Out:
# age               float64
# workclass         float64
# fnlwgt            float64
# education         float64
# education_num     float64
# Marital_Status    float64
# occupation        float64
# relationship      float64
# race              float64
# Capital_gain      float64
# Capital_loss      float64
# hours_per_week    float64
# native_country    float64
# income             object
# dtype: object

# %%
a.income.value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
def encode_target(x):
    if x == "<=50K":
        return 1
    elif x == ">50K":
        return 0

# %%
a['income']=a['income'].apply(encode_target)

# %%
a
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      2.524041  -0.131832 -0.432543   0.082857      -0.482678
# 1      1.160391  -0.131832 -0.346625  -1.450510      -2.214234
# 2      0.323623  -0.131832  0.804562   1.400923      -0.091105
# 3     -0.218002  -0.131832  0.409650   0.082857      -0.482678
# 4      0.101174  -0.131832 -0.233334  -2.184811      -1.571889
# ...         ...        ...       ...        ...            ...
# 30157 -1.395283  -0.131832  1.143405   1.400923      -0.091105
# 30158 -0.855539  -0.131832  0.746620  -1.005534       0.729630
# 30159  0.250941  -0.131832 -0.192734   0.082857      -0.482678
# 30160  1.385457  -0.131832 -0.219182   0.082857      -0.482678
# 30161 -1.395283  -0.131832  0.271981   0.082857      -0.482678
#
#        Marital_Status  occupation  relationship      race  Capital_gain  \
# 0            2.199022   -0.637186      0.167201  0.403721     -0.303112
# 1           -1.772177    0.132682      1.362691  0.403721     -0.303112
# 2            1.577217    0.783631      1.110955  0.403721     -0.303112
# 3           -1.772177    0.359605      1.362691  0.403721     -0.303112
# 4            1.577217   -1.704190      1.362691  0.403721     -0.303112
# ...               ...         ...           ...       ...           ...
# 30157        0.944731    0.983514      0.167201  0.403721     -0.303112
# 30158       -0.363225    1.363832      1.552174  0.403721     -0.303112
# 30159       -0.363225    0.132682     -1.081627  0.403721     -0.303112
# 30160        2.199022   -1.704190      1.362691  0.403721     -0.303112
# 30161        0.944731   -1.704190      1.110955  0.403721     -0.303112
#
#        Capital_loss  hours_per_week  native_country  income
# 0          4.487388       -1.932735        0.297796       1
# 1          4.487388       -0.071034        0.297796       1
# 2          4.487388       -0.071034        0.297796       1
# 3          4.487388        0.344869        0.297796       1
# 4          4.487388       -0.071034        0.297796       1
# ...             ...             ...             ...     ...
# 30157     -0.222847       -0.071034        0.297796       1
# 30158     -0.222847       -0.237999        0.297796       1
# 30159     -0.222847       -0.071034        0.297796       0
# 30160     -0.222847       -0.071034        0.297796       1
# 30161     -0.222847       -1.760659        0.297796       1
#
# [30162 rows x 14 columns]

# %%
plt.rcParams["figure.figsize"] = 12,8
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,3)


axes[0,0].set_title("fnlwgt")
axes[0,0].boxplot(a['fnlwgt'])
axes[0,1].set_title("capital.loss")
axes[0,1].boxplot(a['Capital_loss'])
axes[0,2].set_title("hours_per_week")
axes[0,2].boxplot(a['hours_per_week'])



axes[1,0].set_title("education")
axes[1,0].boxplot(a['education'])
axes[1,1].set_title("occupation")
axes[1,1].boxplot(a['occupation'])
axes[1,2].set_title("native_country")
axes[1,2].boxplot(a['native_country'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2124e571e08>,
#   <matplotlib.lines.Line2D at 0x2124e571f48>],
#  'caps': [<matplotlib.lines.Line2D at 0x2124e578d88>,
#   <matplotlib.lines.Line2D at 0x2124e578ec8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2124e520f48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2124e57bd88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2124e57bec8>],
#  'means': []}

# %% [markdown]
# # Finding Outliers

# %%
def outlier(x):
    high=0
    q1 = x.quantile(.25)
    q3 = x.quantile(.75)
    iqr = q3-q1
    low = q1-1.5*iqr
    high += q3+1.5*iqr
    outlier = (x.loc[(x < low) | (x > high)])
    return(outlier)

# %%
outlier(a['hours_per_week']).count()
# Out:
# 7953

# %%
outlier(a['fnlwgt']).count()
# Out:
# 337

# %%
outlier(a['native_country']).count()
# Out:
# 2658

# %%
outlier(a['income']).count()
# Out:
# 7508

# %% [markdown]
# # Removing Outliers

# %%
q1 =a.quantile(.25)
q3 =a.quantile(.75)
iqr = q3-q1

# %%
df_new = a[~((a < (q1 - 1.5 *iqr))  |  (a > (q3+ 1.5 * iqr)))]

# %%
df_new.isna().sum()
# Out:
# age                  0
# workclass         7876
# fnlwgt             337
# education         2245
# education_num       45
# Marital_Status       0
# occupation           0
# relationship         0
# race              4229
# Capital_gain      2538
# Capital_loss      1427
# hours_per_week    7953
# native_country    2658
# income            7508
# dtype: int64

# %%
modeval=int(df_new['workclass'].mode())
df_new.workclass = df_new.workclass.fillna(modeval)

# %%
modeval=int(df_new['fnlwgt'].mode())
df_new.fnlwgt = df_new.fnlwgt.fillna(modeval)

# %%
modeval=int(df_new['education'].mode())
df_new.education = df_new.education.fillna(modeval)

# %%
modeval=int(df_new['education_num'].mode())
df_new.education_num = df_new.education_num.fillna(modeval)

# %%
modeval=int(df_new['race'].mode())
df_new.race = df_new.race.fillna(modeval)

# %%
modeval=int(df_new['Capital_gain'].mode())
df_new.Capital_gain = df_new.Capital_gain.fillna(modeval)

# %%
modeval=int(df_new['Capital_loss'].mode())
df_new.Capital_loss = df_new.Capital_loss.fillna(modeval)

# %%
modeval=int(df_new['hours_per_week'].mode())
df_new.hours_per_week = df_new.hours_per_week.fillna(modeval)

# %%
modeval=int(df_new['native_country'].mode())
df_new.native_country = df_new.native_country.fillna(modeval)

# %%
df_new=df_new.fillna(0)

# %%
df_new.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# Marital_Status    0
# occupation        0
# relationship      0
# race              0
# Capital_gain      0
# Capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df_new.shape
# Out:
# (30162, 14)

# %%
plt.rcParams["figure.figsize"] = 12,8
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,3)


axes[0,0].set_title("fnlwgt")
axes[0,0].boxplot(df_new['fnlwgt'])
axes[0,1].set_title("capital.loss")
axes[0,1].boxplot(df_new['Capital_loss'])
axes[0,2].set_title("hours_per_week")
axes[0,2].boxplot(df_new['hours_per_week'])



axes[1,0].set_title("education")
axes[1,0].boxplot(df_new['education'])
axes[1,1].set_title("occupation")
axes[1,1].boxplot(df_new['occupation'])
axes[1,2].set_title("native_country")
axes[1,2].boxplot(df_new['native_country'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2124f735c08>,
#   <matplotlib.lines.Line2D at 0x2124f73ba08>],
#  'caps': [<matplotlib.lines.Line2D at 0x2124f73bb48>,
#   <matplotlib.lines.Line2D at 0x2124f7419c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2124f6e9a48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2124f741b08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2124f7469c8>],
#  'means': []}

# %%
df_new.income = df_new.income.astype(int)

# %%
df_new.dtypes
# Out:
# age               float64
# workclass         float64
# fnlwgt            float64
# education         float64
# education_num     float64
# Marital_Status    float64
# occupation        float64
# relationship      float64
# race              float64
# Capital_gain      float64
# Capital_loss      float64
# hours_per_week    float64
# native_country    float64
# income              int32
# dtype: object

# %%
df_new
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      2.524041  -0.131832 -0.432543   0.082857      -0.482678
# 1      1.160391  -0.131832 -0.346625  -1.450510      -2.214234
# 2      0.323623  -0.131832  0.804562   1.400923      -0.091105
# 3     -0.218002  -0.131832  0.409650   0.082857      -0.482678
# 4      0.101174  -0.131832 -0.233334   0.000000      -1.571889
# ...         ...        ...       ...        ...            ...
# 30157 -1.395283  -0.131832  1.143405   1.400923      -0.091105
# 30158 -0.855539  -0.131832  0.746620  -1.005534       0.729630
# 30159  0.250941  -0.131832 -0.192734   0.082857      -0.482678
# 30160  1.385457  -0.131832 -0.219182   0.082857      -0.482678
# 30161 -1.395283  -0.131832  0.271981   0.082857      -0.482678
#
#        Marital_Status  occupation  relationship      race  Capital_gain  \
# 0            2.199022   -0.637186      0.167201  0.403721     -0.303112
# 1           -1.772177    0.132682      1.362691  0.403721     -0.303112
# 2            1.577217    0.783631      1.110955  0.403721     -0.303112
# 3           -1.772177    0.359605      1.362691  0.403721     -0.303112
# 4            1.577217   -1.704190      1.362691  0.403721     -0.303112
# ...               ...         ...           ...       ...           ...
# 30157        0.944731    0.983514      0.167201  0.403721     -0.303112
# 30158       -0.363225    1.363832      1.552174  0.403721     -0.303112
# 30159       -0.363225    0.132682     -1.081627  0.403721     -0.303112
# 30160        2.199022   -1.704190      1.362691  0.403721     -0.303112
# 30161        0.944731   -1.704190      1.110955  0.403721     -0.303112
#
#        Capital_loss  hours_per_week  native_country  income
# 0          0.000000        0.000000        0.297796       1
# 1          0.000000       -0.071034        0.297796       1
# 2          0.000000       -0.071034        0.297796       1
# 3          0.000000        0.344869        0.297796       1
# 4          0.000000       -0.071034        0.297796       1
# ...             ...             ...             ...     ...
# 30157     -0.222847       -0.071034        0.297796       1
# 30158     -0.222847       -0.237999        0.297796       1
# 30159     -0.222847       -0.071034        0.297796       0
# 30160     -0.222847       -0.071034        0.297796       1
# 30161     -0.222847        0.000000        0.297796       1
#
# [30162 rows x 14 columns]

# %% [markdown]
# # Seperation X and Y

# %%
x = df_new.drop(['income'],axis=1)
y = df_new['income']

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 30157    1
# 30158    1
# 30159    0
# 30160    1
# 30161    1
# Name: income, Length: 30162, dtype: int32

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
# from imblearn.over_sampling import RandomOverSampler
# smote = RandomOverSampler()
# x_smote, y_smote = smote.fit_sample(x_train,y_train)

# %%
# from collections import Counter
# print("Before smote:",Counter(y_train))
# print("After smote:",Counter(y_smote))

# %% [markdown]
# # Model Pipeline Before SMOTE

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
pipeline_lr=Pipeline([('lr_classifier',LogisticRegression(random_state=0))])
pipeline_dt=Pipeline([('dt_classifier',DecisionTreeClassifier())])
pipeline_rf=Pipeline([('rf_classifier',RandomForestClassifier())])
pipeline_Nb=Pipeline([('Nb_Gaussion',GaussianNB())])
pipeline_XGb=Pipeline([('XGb_classifier',XGBClassifier())])

# %%
pipelines = [pipeline_lr, pipeline_dt, pipeline_rf,pipeline_Nb,pipeline_XGb]

# %%
best_accuracy=0.0
best_classifier=0
best_pipeline=""
pipe_dict = {0: 'Logistic Regression', 1: 'Decision Tree', 2: 'RandomForest',3:'GaussianNB',4:'XGBClassifier'}

# %%
for pipe in pipelines:
    pipe.fit(x_train, y_train)

# %%
for i,model in enumerate(pipelines):
    print("{} Test Accuracy: {}".format(pipe_dict[i],model.score(x_test,y_test)))
    print(classification_report(y_test,model.predict(x_test)))
# Out:
# Logistic Regression Test Accuracy: 0.8164438059454083
#               precision    recall  f1-score   support
#
#            0       0.70      0.48      0.57      2295
#            1       0.84      0.93      0.88      6754
#
#     accuracy                           0.82      9049
#    macro avg       0.77      0.71      0.73      9049
# weighted avg       0.81      0.82      0.80      9049
#
# Decision Tree Test Accuracy: 0.7768814233616974
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56      2295
#            1       0.85      0.85      0.85      6754
#
#     accuracy                           0.78      9049
#    macro avg       0.71      0.71      0.71      9049
# weighted avg       0.78      0.78      0.78      9049
#
# RandomForest Test Accuracy: 0.8214167311305116
#               precision    recall  f1-score   support
#
#            0       0.67      0.59      0.62      2295
#            1       0.86      0.90      0.88      6754
#
#     accuracy                           0.82      9049
#    macro avg       0.77      0.74      0.75      9049
# weighted avg       0.82      0.82      0.82      9049
#
# GaussianNB Test Accuracy: 0.7947839540280695
#               precision    recall  f1-score   support
#
#            0       0.60      0.57      0.59      2295
#            1       0.86      0.87      0.86      6754
#
#     accuracy                           0.79      9049
#    macro avg       0.73      0.72      0.72      9049
# weighted avg       0.79      0.79      0.79      9049
#
# XGBClassifier Test Accuracy: 0.835340921648801
#               precision    recall  f1-score   support
#
#            0       0.71      0.60      0.65      2295
#            1       0.87      0.91      0.89      6754
#
#     accuracy                           0.84      9049
#    macro avg       0.79      0.76      0.77      9049
# weighted avg       0.83      0.84      0.83      9049

# %%
XGBModel = XGBClassifier(n_estimators=100,learning_rate=0.18,max_depth=6)
XGBModel.fit(x_train, y_train)
y_predXg = XGBModel.predict(x_test)
print("XGB:",classification_report(y_test,y_predXg),confusion_matrix(y_test, y_predXg))
# Out:
# XGB:               precision    recall  f1-score   support
#
#            0       0.71      0.61      0.66      2295
#            1       0.87      0.92      0.89      6754
#
#     accuracy                           0.84      9049
#    macro avg       0.79      0.76      0.78      9049
# weighted avg       0.83      0.84      0.83      9049
#  [[1405  890]
#  [ 568 6186]]

# %%
rfmodel = RandomForestClassifier(n_estimators=100,
    criterion='gini',
    max_depth=6,
    min_samples_split=5,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.5,
    max_features='sqrt',
    max_leaf_nodes=5)
rfmodel.fit(x_train, y_train)
rf_pred = XGBModel.predict(x_test)
print("XGB:",classification_report(y_test,rf_pred),confusion_matrix(y_test,rf_pred))
# Out:
# XGB:               precision    recall  f1-score   support
#
#            0       0.71      0.61      0.66      2295
#            1       0.87      0.92      0.89      6754
#
#     accuracy                           0.84      9049
#    macro avg       0.79      0.76      0.78      9049
# weighted avg       0.83      0.84      0.83      9049
#  [[1405  890]
#  [ 568 6186]]

# %%
# import pickle
# pickle.dump(rfmodel,open('rmodel.pkl','wb'))

# %%
for i,model in enumerate(pipelines):
    if model.score(x_test,y_test)>best_accuracy:
        best_accuracy=model.score(x_test,y_test)
        best_pipeline=model
        best_classifier=i
print('Classifier with best accuracy:{}'.format(pipe_dict[best_classifier]))
# Out:
# Classifier with best accuracy:XGBClassifier

# %% [markdown]
# # After SMOTE Over Sampling

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_train_smote, y_train_smote = smote.fit_sample(x_train,y_train)

# %%
smote = SMOTE()

# %%
x_train_smote, y_train_smote = smote.fit_sample(x_train,y_train)

# %%
from collections import Counter
print("Before smote:",Counter(y_train))
print("After smote:",Counter(y_train_smote))
# Out:
# Before smote: Counter({1: 15900, 0: 5213})
# After smote: Counter({0: 15900, 1: 15900})

# %%
# x_train_smote = x_train_smote.drop(['age'],axis=1)

# %% [markdown]
# # Model Building

# %%
pipeline_lr1=Pipeline([('lr_classifier',LogisticRegression(random_state=0))])
pipeline_dt1=Pipeline([('dt_classifier',DecisionTreeClassifier())])
pipeline_rf1=Pipeline([('rf_classifier',RandomForestClassifier())])
pipeline_Nb1=Pipeline([('Nb_Gaussion',GaussianNB())])
pipeline_XGb1=Pipeline([('XGb_classifier',XGBClassifier())])

# %%
pipelines1 = [pipeline_lr1, pipeline_dt1, pipeline_rf1,pipeline_Nb1,pipeline_XGb1]

# %%
best_accuracy1=0.0
best_classifier1=0
best_pipeline1=""
pipe_dict1 = {0: 'Logistic Regression', 1: 'Decision Tree', 2: 'RandomForest',3:'GaussianNB',4:'XGBClassifier'}

# %%
for pipe in pipelines1:
    pipe.fit(x_train_smote, y_train_smote)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
for i,model in enumerate(pipelines1):
    print("{} Test Accuracy: {}".format(pipe_dict1[i],model.score(x_test,y_test)))
    print(classification_report(y_test,model.predict(x_test)))
# Out:
# Logistic Regression Test Accuracy: 0.7614101005635981
#               precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63      2295
#            1       0.91      0.75      0.82      6754
#
#     accuracy                           0.76      9049
#    macro avg       0.72      0.77      0.73      9049
# weighted avg       0.81      0.76      0.77      9049
#
# Decision Tree Test Accuracy: 0.7733451210078461
#               precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56      2295
#            1       0.85      0.84      0.85      6754
#
#     accuracy                           0.77      9049
#    macro avg       0.70      0.71      0.70      9049
# weighted avg       0.78      0.77      0.77      9049
#
# RandomForest Test Accuracy: 0.8187645043651233
#               precision    recall  f1-score   support
#
#            0       0.65      0.63      0.64      2295
#            1       0.88      0.88      0.88      6754
#
#     accuracy                           0.82      9049
#    macro avg       0.76      0.76      0.76      9049
# weighted avg       0.82      0.82      0.82      9049
#
# GaussianNB Test Accuracy: 0.750359155707813
#               precision    recall  f1-score   support
#
#            0       0.51      0.77      0.61      2295
#            1       0.90      0.75      0.82      6754
#
#     accuracy                           0.75      9049
#    macro avg       0.70      0.76      0.71      9049
# weighted avg       0.80      0.75      0.76      9049
#
# XGBClassifier Test Accuracy: 0.8302574870151398
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66      2295
#            1       0.88      0.89      0.89      6754
#
#     accuracy                           0.83      9049
#    macro avg       0.78      0.77      0.77      9049
# weighted avg       0.83      0.83      0.83      9049

# %%
for i,model in enumerate(pipelines1):
    if model.score(x_test,y_test)>best_accuracy1:
        best_accuracy1=model.score(x_test,y_test)
        best_pipeline1=model
        best_classifier1=i
print('Classifier with best accuracy:{}'.format(pipe_dict1[best_classifier1]))
# Out:
# Classifier with best accuracy:XGBClassifier

# %% [markdown]
# ### Indiviual Report by tweeking parametrs

# %%
Classmodel = RandomForestClassifier(n_estimators = 100, random_state = 42)
Classmodel.fit(x_train_smote, y_train_smote)
y_pred = Classmodel.predict(x_test)
print("RF:",classification_report(y_pred,y_test),confusion_matrix(y_test, y_pred))
# Out:
# RF:               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64      2233
#            1       0.88      0.88      0.88      6816
#
#     accuracy                           0.82      9049
#    macro avg       0.76      0.76      0.76      9049
# weighted avg       0.82      0.82      0.82      9049
#  [[1445  850]
#  [ 788 5966]]

# %%
classifier = GaussianNB()
classifier.fit(x_train_smote, y_train_smote)
y_predNB = classifier.predict(x_test)
print("NB:",classification_report(y_predNB,y_test),confusion_matrix(y_test, y_predNB))
# Out:
# NB:               precision    recall  f1-score   support
#
#            0       0.77      0.51      0.61      3476
#            1       0.75      0.90      0.82      5573
#
#     accuracy                           0.75      9049
#    macro avg       0.76      0.70      0.71      9049
# weighted avg       0.75      0.75      0.74      9049
#  [[1756  539]
#  [1720 5034]]

# %%
XGBModel = XGBClassifier(n_estimators=110,learning_rate=0.05,max_depth=3)
XGBModel.fit(x_train_smote, y_train_smote)
y_predXg = XGBModel.predict(x_test)
print("XGB:",classification_report(y_predXg,y_test),confusion_matrix(y_test, y_predXg))
# Out:
# XGB:               precision    recall  f1-score   support
#
#            0       0.78      0.59      0.67      3054
#            1       0.81      0.92      0.86      5995
#
#     accuracy                           0.81      9049
#    macro avg       0.80      0.75      0.77      9049
# weighted avg       0.80      0.81      0.80      9049
#  [[1795  500]
#  [1259 5495]]

# %%
# import pickle
# pickle.dump(XGBModel,open('XGBModel.pkl','wb'))

# %% [markdown]
# ### **Connect With Me in Linkedin** :- https://www.linkedin.com/in/dheerajkumar1997/
